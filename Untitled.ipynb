# %%
import train_overfit
# Out:
# Using TensorFlow backend.

# %%
args = train_overfit.argparser.parse_known_args()[0]
args.data_path = '../voc/VOCdevkit/pascal_voc_07_12.hdf5'
train_overfit._main(args)
# Out:
# Boxes:
# [[  0.16         0.51355422   0.296        0.68975904  14.        ]
#  [  0.428        0.47590361   0.276        0.60240964  14.        ]
#  [  0.664        0.5813253    0.432        0.8373494   14.        ]
#  [  0.863        0.64457831   0.274        0.71084337  14.        ]]
# Box corners:
# [[ 56   6 285 154  14]
#  [ 58 145 258 283  14]
#  [ 54 224 332 440  14]
#  [ 96 363 332 500  14]]
# Active detectors:
# (array([6, 6, 7, 8]), array([ 2,  5,  8, 11]), array([2, 2, 4, 2]))
# Matching boxes for active detectors:
# [[  0.08         0.6762048    0.14205289   0.49346468  14.        ]
#  [  0.56400001   0.18674698   0.07209431   0.35806003  14.        ]
#  [  0.63200003   0.55722892  -0.55375004   0.1716858   14.        ]
#  [  0.219        0.37951806   0.06482155   0.52357447  14.        ]]
# Epoch 1/100
# 1/1 [==============================] - 8s 8s/step - loss: 133.1255
# Epoch 2/100
# 1/1 [==============================] - 0s 103ms/step - loss: 1015.2667
# Epoch 3/100
# ...
