# %%
import test_yolo
# Out:
# Using TensorFlow backend.

# %%
args = test_yolo.parser.parse_known_args()[0]
args.model_path = 'trained_stage_2.h5'
args.test_path = 'test_img'
args.output_path = 'test_img/out'
args.classes_path = 'model_data/pascal_classes.txt'
t = test_yolo._main(args)
# Out:
# /opt/conda/lib/python3.6/site-packages/keras/models.py:255: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# trained_stage_2.h5 model, anchors, and classes loaded.

# %%
i = 5
print(t[1][i])
t[0][i]
# Out:
# []
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x333 at 0x7FB7944BDE80>
